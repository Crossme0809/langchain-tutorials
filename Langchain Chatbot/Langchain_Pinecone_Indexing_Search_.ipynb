# %% [markdown]
# <a href="https://colab.research.google.com/github/Crossme0809/langchain-tutorials/blob/main/Langchain_Pinecone_Indexing_Search_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade langchain openai  -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.7 MB/s eta 0:00:00

# %%
# !pip install sentence_transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 69.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.3 MB/s eta 0:00:00
# ...

# %%
# !pip install unstructured -q
# !pip install unstructured[local-inference] -q
# !pip install detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 43.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 34.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 46.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 61.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.1/238.1 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 668.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 15 not upgraded.
# Need to get 174 kB of archives.
# After this operation, 754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.1 [174 kB]
# Fetched 174 kB in 0s (360 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.1_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.1) ...
# Setting up poppler-utils (0.86.1-0ubuntu1.1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %% [markdown]
# https://python.langchain.com/en/latest/modules/indexes/document_loaders/examples/directory_loader.html

# %%
# !pip show pillow
# !pip uninstall pillow
# !pip install --upgrade pillow==6.2.2
# Out:
# Name: Pillow
# Version: 9.5.0
# Summary: Python Imaging Library (Fork)
# Home-page: https://python-pillow.org
# Author: Jeffrey A. Clark (Alex)
# Author-email: aclark@aclark.net
# License: HPND
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by: bokeh, detectron2, dopamine-rl, fastai, fvcore, imageio, imgaug, layoutparser, matplotlib, pdf2image, pdfplumber, pytesseract, python-pptx, scikit-image, torchvision, unstructured, wordcloud
# Found existing installation: Pillow 9.5.0
# Uninstalling Pillow-9.5.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/PIL/*
#     /usr/local/lib/python3.10/dist-packages/Pillow-9.5.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libXau-154567c4.so.6.0.0
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libbrotlicommon-92722cb2.so.1
#     /usr/local/lib/python3.10/dist-packages/Pillow.libs/libbrotlidec-db4b3db6.so.1.0.9
# ...

# %%
from langchain.document_loaders import DirectoryLoader

directory = '/content/data'

def load_docs(directory):
  loader = DirectoryLoader(directory)
  documents = loader.load()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# 1

# %% [markdown]
# https://python.langchain.com/en/latest/modules/indexes/text_splitters/getting_started.html

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents,chunk_size=500,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 22

# %%
print(docs[8].page_content)
# Out:
# 最常⽤的链类型是 LLMChain，它结合了 PromptTemplate、Model 和 Guardrails 以获取⽤户输⼊，相应地格式化， 将其传递给模型并获得响应，然后验证和修复（如有必要）模型输出。
#
# Chain（链）
#
# 链只是多个单独组件的端到端包装器。
#
# LLMChain（LLM 链）
#
# LLMChain 是最常⻅的链类型。它由⼀个 PromptTemplate、⼀个模型（LLM 或 ChatModel）和⼀个可选的输出解析 器组成。此链采⽤多个输⼊变量，使⽤ PromptTemplate 将它们格式化为提示。然后它将其传递给模型。最后，它 使⽤ OutputParser（如果提供）将 LLM 的输出解析为最终格式。
#
# Index-related chains（索引相关链）
#
# 此类链⽤于与索引交互。这些链的⽬的是将您⾃⼰的数据（存储在索引中）与 LLM 相结合。最好的例⼦是对您⾃ ⼰的⽂档进⾏问答。

# %%
#requires for open ai embedding
# !pip install tiktoken -q

# %%
# import openai
# from langchain.embeddings.openai import OpenAIEmbeddings
# embeddings = OpenAIEmbeddings(model_name="ada")
from langchain.embeddings import SentenceTransformerEmbeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
query_result = embeddings.embed_query("如何安装LangChain")
len(query_result)
# Out:
# 384

# %%
# !pip install pinecone-client -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 18.5 MB/s eta 0:00:00

# %% [markdown]
# https://python.langchain.com/en/latest/modules/indexes/vectorstores/examples/pinecone.html

# %%
import pinecone
from langchain.vectorstores import Pinecone
# initialize pinecone
pinecone.init(
    api_key="your-pinecone-key",  # find at app.pinecone.io
    environment="us-east-1-aws"  # next to api key in console
)

index_name = "langchain-chatbot"

index = Pinecone.from_documents(docs, embeddings, index_name=index_name)

# %%
def get_similiar_docs(query,k=1,score=False):
  if score:
    similar_docs = index.similarity_search_with_score(query,k=k)
  else:
    similar_docs = index.similarity_search(query,k=k)
  return similar_docs

query = "管理LLM的提示"
similar_docs = get_similiar_docs(query)
similar_docs
# Out:
# [Document(page_content='个提示（假设⽣成这样⼀个响应的提示）并将其解析为某种结构。提示主要是在 OutputParser 想要以某种⽅ 式重试或修复输出的情况下提供的，并且需要来⾃提示的信息才能这样做。\n\nIndexs\n\n索引指的是构建⽂档的⽅式，以便 LLM 可以最好地与它们交互。该模块包含⽤于处理⽂档、不同类型索引的实⽤ 函数，以及在链中使⽤这些索引的示例。\n\n在链中使⽤索引的最常⻅⽅式是在“检索”步骤中。此步骤指的是接受⽤户的查询并返回最相关的⽂档。我们之所以 做出这种区分，是因为 （1） 索引可以⽤于检索以外的其他⽤途，以及 （2） 检索可以使⽤索引以外的其他逻辑来 查找相关⽂档。因此，我们有⼀个“检索器”接⼝的概念——这是⼤多数链使⽤的接⼝。\n\n⼤多数时候，当我们谈论索引和检索时，我们谈论的是索引和检索⾮结构化数据（如⽂本⽂档）。要与结构化数据\n\n（SQL 表等）或 API 进⾏交互，请参阅相应的⽤例部分以获取相关功能的链接。LangChain ⽀持的主要索引和检索 类型⽬前以⽮量数据库为中⼼，因此我们深⼊研究了这些主题的许多功能。\n\nDocument Loaders（⽂档加载器）', metadata={'source': '/content/data/LangChain 概念篇.pdf'})]
